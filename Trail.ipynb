# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
print(os.listdir("./input"))

import lightgbm as lgb
from sklearn.model_selection import *
from sklearn.metrics import mean_squared_error, make_scorer
from scipy.stats import mode, skew, kurtosis, entropy
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.metrics import mean_squared_error

import matplotlib.pyplot as plt
import seaborn as sns

import dask.dataframe as dd
from dask.multiprocessing import get

from tqdm import tqdm, tqdm_notebook
tqdm.pandas(tqdm_notebook)
# Out:
# ['sample_submission.csv', 'test.csv', 'train.csv']

# %%
train = pd.read_csv("./input/train.csv")
test = pd.read_csv("./input/test.csv")

transact_cols = [f for f in train.columns if f not in ["ID", "target"]]
y = np.log1p(train["target"]).values

# %%
cols = ['f190486d6', '58e2e02e6', 'eeb9cd3aa', '9fd594eec', '6eef030c1',
       '15ace8c9f', 'fb0f5dbfe', '58e056e12', '20aa07010', '024c577b9',
       'd6bb78916', 'b43a7cfd5', '58232a6fb', '1702b5bf0', '324921c7b', 
       '62e59a501', '2ec5b290f', '241f0f867', 'fb49e4212',  '66ace2992',
       'f74e8f13d', '5c6487af1', '963a49cdc', '26fc93eb7', '1931ccfdd', 
       '703885424', '70feb1494', '491b9ee45', '23310aa6f', 'e176a204a',
       '6619d81fc', '1db387535', 'fc99f9426', '91f701ba2',  '0572565c2',
       '190db8488',  'adb64ff71', 'c47340d97', 'c5a231d81', '0ff32eb98']

# %%
def _get_leak(df, cols, lag=0):
    d1 = df[cols[:-lag-2]].apply(tuple, axis=1).to_frame().rename(columns={0: 'key'})
    d2 = df[cols[lag+2:]].apply(tuple, axis=1).to_frame().rename(columns={0: 'key'})
    d2['pred'] = df[cols[lag]]
    d2 = d2[d2.pred != 0] ### to make output consistent with Hasan's function
    d3 = d2[~d2.duplicated(['key'], keep='first')]
    return d1.merge(d3, how='left', on='key').pred.fillna(0)

# %%
test["target"] = train["target"].mean()

all_df = pd.concat([train, test]).reset_index(drop=True)

# %%
def compiled_leak_result():
    
    max_nlags = len(cols) - 2
    all_leak = all_df[["ID", "target"] + cols]
    all_leak["compiled_leak"] = 0
    all_leak["nonzero_mean"] = all_df[transact_cols].apply(
        lambda x: np.expm1(np.log1p(x[x!=0]).mean()), axis=1
    )
    
    scores = []
    leaky_value_counts = []
    leaky_value_corrects = []
    leaky_cols = []
    
    for i in range(max_nlags):
        c = "leaked_target_"+str(i)
        
        print('Processing lag', i)
        all_leak[c] = _get_leak(all_leak, cols, i)
        
        leaky_cols.append(c)
        all_leak = all_df.join(
            all_leak.set_index("ID")[leaky_cols+["compiled_leak", "nonzero_mean"]], 
            on="ID", how="left"
        )[["ID", "target"] + cols + leaky_cols+["compiled_leak", "nonzero_mean"]]
        
        zeroleak = all_leak["compiled_leak"]==0
        all_leak.loc[zeroleak, "compiled_leak"] = all_leak.loc[zeroleak, c]
        
        train_leak = train.join(all_leak.set_index("ID")[leaky_cols+["compiled_leak", "nonzero_mean"]]
                                , on="ID", how="left"
                               )[["ID", "target"] + cols + leaky_cols+["compiled_leak", "nonzero_mean"]]
        
        leaky_value_counts.append(sum(train_leak["compiled_leak"] > 0))
        _correct_counts = sum(train_leak["compiled_leak"]==train_leak["target"])
        leaky_value_corrects.append(_correct_counts/leaky_value_counts[-1])
        print("Leak values found in train & test: ", leaky_value_counts[-1], 
              sum(all_leak["compiled_leak"] > 0) - leaky_value_counts[-1])
        print(
            "% of correct leaks values in train ", 
            leaky_value_corrects[-1]
        )
        tmp = train_leak.copy()
        tmp.loc[zeroleak, "compiled_leak"] = tmp.loc[zeroleak, "nonzero_mean"]
        scores.append(np.sqrt(mean_squared_error(y, np.log1p(tmp["compiled_leak"]).fillna(14.49))))
        print(
            'Score (filled with nonzero mean)', 
            scores[-1]
        )
    result = dict(
        score=scores, 
        leaky_count=leaky_value_counts,
        leaky_correct=leaky_value_corrects,
    )
    return all_leak, result

# %%
all_leak, result = compiled_leak_result()
# Out:
# Processing lag 0
# Leak values found in train & test:  1719 26071
# % of correct leaks values in train  0.796393251890634
# Score (filled with nonzero mean) 1.5138333391635188
# Processing lag 1
# Leak values found in train & test:  2334 27469
# % of correct leaks values in train  0.8410454155955441
# Score (filled with nonzero mean) 1.2851148974795277
# Processing lag 2
# Leak values found in train & test:  2726 28335
# % of correct leaks values in train  0.8606016140865738
# Score (filled with nonzero mean) 1.1731452616255769
# Processing lag 3
# Leak values found in train & test:  2974 28996
# % of correct leaks values in train  0.8702084734364492
# Score (filled with nonzero mean) 1.0846181414970784
# Processing lag 4
# Leak values found in train & test:  3148 29528
# % of correct leaks values in train  0.875158831003812
# Score (filled with nonzero mean) 1.0371119114150071
# Processing lag 5
# Leak values found in train & test:  3304 29957
# % of correct leaks values in train  0.8768159806295399
# Score (filled with nonzero mean) 1.0047389116116845
# Processing lag 6
# Leak values found in train & test:  3426 30273
# % of correct leaks values in train  0.8771161704611792
# Score (filled with nonzero mean) 0.9662847228932259
# Processing lag 7
# Leak values found in train & test:  3529 30544
# % of correct leaks values in train  0.8778690847265515
# Score (filled with nonzero mean) 0.9259205702808162
# Processing lag 8
# Leak values found in train & test:  3617 30831
# % of correct leaks values in train  0.8775228089576997
# Score (filled with nonzero mean) 0.908648006242534
# Processing lag 9
# Leak values found in train & test:  3672 31106
# % of correct leaks values in train  0.8774509803921569
# Score (filled with nonzero mean) 0.8933908586434565
# Processing lag 10
# Leak values found in train & test:  3737 31352
# % of correct leaks values in train  0.8777093925608777
# Score (filled with nonzero mean) 0.8857203548248191
# Processing lag 11
# Leak values found in train & test:  3787 31583
# % of correct leaks values in train  0.8766833905466068
# Score (filled with nonzero mean) 0.8730137881941101
# Processing lag 12
# Leak values found in train & test:  3843 31791
# % of correct leaks values in train  0.8743169398907104
# Score (filled with nonzero mean) 0.8629981510837599
# Processing lag 13
# Leak values found in train & test:  3879 32025
# % of correct leaks values in train  0.8736787831915442
# Score (filled with nonzero mean) 0.8686525639673124
# Processing lag 14
# Leak values found in train & test:  3922 32238
# % of correct leaks values in train  0.8722590515043345
# Score (filled with nonzero mean) 0.8608666364660603
# Processing lag 15
# Leak values found in train & test:  3947 32439
# % of correct leaks values in train  0.8707879402077527
# Score (filled with nonzero mean) 0.8512431469808788
# Processing lag 16
# Leak values found in train & test:  3970 32672
# % of correct leaks values in train  0.8695214105793451
# Score (filled with nonzero mean) 0.8547977988846622
# Processing lag 17
# Leak values found in train & test:  4005 32904
# % of correct leaks values in train  0.8671660424469413
# Score (filled with nonzero mean) 0.8495255105910401
# Processing lag 18
# Leak values found in train & test:  4031 33090
# % of correct leaks values in train  0.8652939717191764
# Score (filled with nonzero mean) 0.8473031361831777
# Processing lag 19
# Leak values found in train & test:  4056 33316
# % of correct leaks values in train  0.8636587771203156
# Score (filled with nonzero mean) 0.8474659927225883
# Processing lag 20
# Leak values found in train & test:  4078 33536
# % of correct leaks values in train  0.8621873467385973
# Score (filled with nonzero mean) 0.8516340574332173
# Processing lag 21
# Leak values found in train & test:  4105 33773
# % of correct leaks values in train  0.8594397076735688
# Score (filled with nonzero mean) 0.8495155180428469
# Processing lag 22
# Leak values found in train & test:  4124 34042
# % of correct leaks values in train  0.8576624636275461
# Score (filled with nonzero mean) 0.8468959707608168
# Processing lag 23
# Leak values found in train & test:  4144 34298
# % of correct leaks values in train  0.8561776061776062
# Score (filled with nonzero mean) 0.8478633452152057
# Processing lag 24
# Leak values found in train & test:  4165 34574
# % of correct leaks values in train  0.8535414165666266
# Score (filled with nonzero mean) 0.8484419054981213
# Processing lag 25
# Leak values found in train & test:  4189 34887
# % of correct leaks values in train  0.8503222726187635
# Score (filled with nonzero mean) 0.8601847341565682
# Processing lag 26
# Leak values found in train & test:  4213 35224
# % of correct leaks values in train  0.8461903631616425
# Score (filled with nonzero mean) 0.8690424433383295
# Processing lag 27
# Leak values found in train & test:  4232 35605
# % of correct leaks values in train  0.843336483931947
# Score (filled with nonzero mean) 0.877055669463137
# Processing lag 28
# Leak values found in train & test:  4251 36024
# % of correct leaks values in train  0.8405081157374735
# Score (filled with nonzero mean) 0.8753021975816955
# Processing lag 29
# Leak values found in train & test:  4266 36503
# % of correct leaks values in train  0.8380215658696671
# Score (filled with nonzero mean) 0.8770391879577772
# Processing lag 30
# Leak values found in train & test:  4284 37104
# % of correct leaks values in train  0.8349673202614379
# Score (filled with nonzero mean) 0.884255716499442
# Processing lag 31
# Leak values found in train & test:  4304 37794
# % of correct leaks values in train  0.8310873605947955
# Score (filled with nonzero mean) 0.8868175719786691
# Processing lag 32
# Leak values found in train & test:  4319 38630
# % of correct leaks values in train  0.8282009724473258
# Score (filled with nonzero mean) 0.9008711297599149
# Processing lag 33
# Leak values found in train & test:  4348 39752
# % of correct leaks values in train  0.8229070837166513
# Score (filled with nonzero mean) 0.9040490415079568
# Processing lag 34
# Leak values found in train & test:  4368 41221
# % of correct leaks values in train  0.8193681318681318
# Score (filled with nonzero mean) 0.9164115256727089
# Processing lag 35
# Leak values found in train & test:  4388 43029
# % of correct leaks values in train  0.8158614402917046
# Score (filled with nonzero mean) 0.9218389428014993
# Processing lag 36
# Leak values found in train & test:  4415 45319
# % of correct leaks values in train  0.8110985277463194
# Score (filled with nonzero mean) 0.9297829906811931
# Processing lag 37
# Leak values found in train & test:  4447 48087
# % of correct leaks values in train  0.8052619743647402
# Score (filled with nonzero mean) 0.9461909236541302

# %%
best_score = np.min(result['score'])
best_lag = np.argmin(result['score'])
print('best_score', best_score, '\nbest_lag', best_lag)
# Out:
# best_score 0.8468959707608168
# best_lag 22

# %%
def rewrite_compiled_leak(leak_df, lag):
    leak_df["compiled_leak"] = 0
    for i in range(lag):
        c = "leaked_target_"+str(i)
        zeroleak = leak_df["compiled_leak"]==0
        leak_df.loc[zeroleak, "compiled_leak"] = leak_df.loc[zeroleak, c]
    return leak_df

# %%
leaky_cols = [c for c in all_leak.columns if 'leaked_target_' in c]

# %%
all_leak_best_lag = rewrite_compiled_leak(all_leak, best_lag)
test_leak = test.join(
            all_leak_best_lag.set_index("ID")[leaky_cols+["compiled_leak", "nonzero_mean"]], 
            on="ID", how="left"
        )[["ID", "target"] + cols + leaky_cols+["compiled_leak", "nonzero_mean"]]
test_leak.head()

# %%
test_leak.loc[test_leak["compiled_leak"]==0, "compiled_leak"] = test_leak.loc[test_leak["compiled_leak"]==0, "nonzero_mean"]
test_leak.head()

# %%
sub = test[["ID"]]
sub["target"] = test_leak["compiled_leak"]
sub.to_csv(f"baseline_sub_lag_{best_lag}.csv", index=False)
print(f"baseline_sub_lag_{best_lag}.csv saved")
